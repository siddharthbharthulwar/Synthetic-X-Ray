# %%
from validation import ValidationDataset

vd = ValidationDataset('Training_128', 'Results_AE_1', 'model_arch.json', 'model_weights.h5')

# %%
vd.view_pair(121)

# %%
vd.compare_histograms(121)

# %%
vd.tpfp(121)
